# %% [markdown]
# # White Noise Filter

# %%
# Get thinkdsp.py

import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %%
import numpy as np
from thinkdsp import play_wave
#play_wave(filename='temp.wav', player='aplay')
from thinkdsp import read_wave
from thinkdsp import decorate

# %% [markdown]
# ## Original Audio

# %%
wave = read_wave(r'original_data.wav')
spect=wave.make_spectrum()
spect.plot()
decorate(xlabel='Frequency (Hz)',ylabel='PSD')
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Noisy Data

# %%
#noisyWave = read_wave(r'noisy1.wav')
#noisyWave = read_wave(r'noisy2.wav')
noisyWave = read_wave(r'noisy3.wav')
spect=noisyWave.make_spectrum()
spect.plot()
decorate(xlabel='Frequency (Hz)',ylabel='PSD')
noisyWave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Filtering

# %%
import matplotlib.pyplot as plt
from IPython.display import display

def WhiteFilter(wave, start, duration, cutoff):
    """Selects a segment from the wave and filters it.
    
    Plots the spectrum and displays an Audio widget.
    
    wave: Wave object
    start: time in s
    duration: time in s
    cutoff: frequency in Hz
    """
    segment = wave.segment(start, duration)
    spectrum = segment.whiteFilterSpect(cutoff)
    spectrum.plot(color='#045a8d')
    decorate(xlabel='Frequency (Hz)')
    plt.show()
    
    audio = spectrum.make_wave().make_audio()
    display(audio)

# %%
from ipywidgets import interact, fixed

#wave 
interact(WhiteFilter, wave=fixed(noisyWave), 
         start=(0, 5, 0.1), duration=(0, 8, 0.1), cutoff=(0,50 , 1));
# Out:
# interactive(children=(FloatSlider(value=2.0, description='start', max=5.0), FloatSlider(value=4.0, description…
